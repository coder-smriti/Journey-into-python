# %%
#capatlize,title,upper,swapcase

# %%
c = "kolkata"
print(c)
# Out:
# kolkata

# %%
c
c.capitalize()
"this is sweet".capitalize()
# Out:
# 'This is sweet'

# %%
"i don't know how too do".title()
# Out:
# "I Don'T Know How Too Do"

# %%
c.upper()
# Out:
# 'KOLKATA'

# %%
c.lower()
# Out:
# 'kolkata'

# %%
"kolkATa".swapcase()
# Out:
# 'KOLKatA'

# %%
#count
"it is not my fault".count("u")
# Out:
# 1

# %%
#find/index
"it is my ability to remove your negativity".find("ability") #-1 when something is not present
# Out:
# 9

# %%
"it is same car as mine".index("s") #error when something is not present
# Out:
# 4

# %%
#endwith/startwith
"This is car".endswith("car")
# Out:
# True

# %%
#format
"Hello, i buy my dream car it is {} and i was only {}".format("lamborgini",25)
# Out:
# 'Hello, i buy my dream car it is lamborgini and i was only 25'

# %%
"Hello, i buy my dream car it is {1} and i was only {0}".format("lamborgini",25)
# Out:
# 'Hello, i buy my dream car it is 25 and i was only lamborgini'

# %%
"Hello, i buy my dream car it is {name} and i was only {age}".format(name="lamborgini",age=25)
# Out:
# 'Hello, i buy my dream car it is lamborgini and i was only 25'

# %%
#isalnum/isalpha/isdecimal/isdigit/isidentifier
"FLAT@&".isalpha()
# Out:
# False

# %%
"20A".isdigit()
# Out:
# False

# %%
"hello_world".isidentifier()
# Out:
# True

# %%
#splitfunction
"who is the prime minister of india".split()
#in qura tag creat krne k liye words ko split kr dega
# Out:
# ['who', 'is', 'the', 'prime', 'minister', 'of', 'india']

# %%
"who is the prime minister of india".split("x")
# Out:
# ['who is the prime minister of india']

# %%
" ".join(['who','is','the','pm','of','india'])
# Out:
# 'who is the pm of india'

# %%
#replace
"Hi my name is smriti".replace("smriti","sanjay")
# Out:
# 'Hi my name is sanjay'

# %%
#strip
name = "      smriti        "
name.strip()
# Out:
# 'smriti'
