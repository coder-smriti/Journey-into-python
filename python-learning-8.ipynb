# %%
def f(y):
    x = 1
    x += 1
    print(x)

x = 5
f(x)
print(x)
# Out:
# 2
# 5

# %%
def g(x):
    def h(x):
        x = x+1
        print("in h(x : x = ",x)
    x = x + 1
    print('in g(x): x = ', x)
    h(x)
    return x

x = 3
z = g(x)
print('in main progres scope: x = ', x)
print('in main progres scope: z = ', z)
# Out:
# in g(x): x =  4
# in h(x : x =  5
# in main progres scope: x =  3
# in main progres scope: z =  4

# %%
#everything in python is an object
#function is also an object

# %%
# function as object
def f(num):
        return num**2

# %%
f(2)
# Out:
# 4

# %%
f(4)
# Out:
# 16

# %%
x = f

# %%
x(2)
# Out:
# 4

# %%
#del f

# %%
#f

# %%
x #call by object refrence
# Out:
# <function __main__.f(num)>

# %%
type(x)
# Out:
# function

# %%
L={1,2,3,4}
L
# Out:
# {1, 2, 3, 4}

# %%
L=[1,2,3,4]
L
# Out:
# [1, 2, 3, 4]

# %%
L
# Out:
# [1, 2, 3, 4]

# %%
L=[1,2,3,4,x]
L
# Out:
# [1, 2, 3, 4, <function __main__.f(num)>]

# %%
L[-1](3)
# Out:
# 9

# %%
L=[1,2,3,4,x(5)]
L
# Out:
# [1, 2, 3, 4, 25]

# %%
# in python we can do so many things in python
#Renaming a function
#Deleting a function
#Storing a fuunction
#Function argument
#returnong a function

# %%
#def func_a():
 #   print('inside func_c')

#def func_c(z):
    #print('inside func_c')
    #return z()

#print(func_c(fun_a))

# %%
def f():
    def x(a,b):
        return a+b
    return x

val = f()(3,4)
print(val)
# Out:
# 7

# %%
#benfits of function
#every function is self control
#code modularity
#code reusebility
#code Readibility
