# %%
#Lamda funuction (anonmus fuction)
#lamda input expression

# %%
x=lambda x:x**2

# %%
x(9)
# Out:
# 81

# %%
a=lambda x,y:x+y
a(4,5)
# Out:
# 9

# %%
#Difference
#1.Lambda haas no return value
#2.one line
#3.code useed for code reusability
#4.No name

# %%
type(a)
# Out:
# function

# %%
#why we use it
#Along with higher order functions(that fuction which is using to return a function)

# %%
b=lambda x:x[0]=='a'
b('applw')
# Out:
# True

# %%
b('banana')
# Out:
# False

# %%
b=lambda x:"Even"if x%2 ==0 else "Odd"
b(3)
# Out:
# 'Odd'

# %%
b(2)
# Out:
# 'Even'

# %%
#Higher order function
def return_sum(L):

    even_sum=0
    odd_sum=0
    div3_sum=0

    for i in L:
        if i%2==0:
            even_sum=even_sum+i
        if i%2!=0:
            odd_sum=odd_sum+i

    return(even_sum.odd)
L=[11,12,13,14,15,26,45,47]

# %% [raw]
# def return_sum(func,L):
#     result=0
#
#     for i  in L:
#         if func(i):
#             result = result+i
#
# return result
#
# L=[11,14,21,23,56,78,45,29,28]
#
# x=lambda x:x%2==0
# y=lambda x:x%2==0
# z=lambda x:x%2==0
#
# print(return_sum(x,L))
# print(return_sum(y,L))
# print(return_sum(z,L))

# %%
def return_sum(func,L):
    result=0

    for i in L:

        if func(i):
            result = result+i

return result

L=[11,14,21,23,56,78,45,29,28]

x=lambda x:x%2==0
y=lambda x:x%2==0
z=lambda x:x%2==0

print(return_sum(x,L))
print(return_sum(y,L))
print(return_sum(z,L))
# Out:
#   File "/tmp/ipykernel_57/3740500864.py", line 9
#     return result
#     ^
# SyntaxError: 'return' outside function

# %%
#map,filter,Reduce,iterable(tuple,dictonary)
L=[1,2,3,4,5,6,7,8]
map(lambda x:x*2,L) #it return map object

# %%
map(lambda x:x*2,L)

# %%
list(map(lambda x:x*2,L))
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16]

# %%
list(map(lambda x:x%2==0,L))
# Out:
# [False, True, False, True, False, True, False, True]

# %%
student=[
{
        "name":"sita",
        "father name":"Vikram",
        "mother name":"ruhi",
        "address":"lucknow",
    },{
        "name":"manni",
        "father name":"Vashu",
        "mother name":"rani",
        "address":"delhi",
    } ,{
        "name":"jagriti",
        "father name":"shanu",
        "mother name":"rubika",
        "address":"ayodhya",
    }
]

# %%
map(lambda student: student['name'],L)

# %%
list(map(lambda student: student,L))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
list(map(lambda student: student['name'],students))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_57/1766638619.py in <cell line: 0>()
# ----> 1 list(map(lambda student: student['name'],students))
#
# NameError: name 'students' is not defined

# %%
#filter
L
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
list(filter(lambda x:x>4,L))
# Out:
# [5, 6, 7, 8]

# %%
fruits=["maat","neet","jam","ssamm"]

# %%
list(filter(lambda fruit:'e' in fruit,fruits))
# Out:
# ['neet']

# %%
 list(filter(lambda fruit:'m' in fruit,fruits))
# Out:
# ['maat', 'jam', 'ssamm']

# %%
#reduce
import functools
L
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
functools.reduce(lambda x,y:x+y,L)
# Out:
# 36

# %%
L1=[11,22,33,44,55,66]
L1
# Out:
# [11, 22, 33, 44, 55, 66]

# %%
functools.reduce(lambda x,y : x if x>y else y,L1)
# Out:
# 66

# %%
functools.reduce(lambda x,y : x if x<y else y,L1)
# Out:
# 11

# %%
#list comprehenshion
L
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
L1=[item*2 for item in L]
L1
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16]

# %%
L2=[i**2 for i in range(10)]
L2
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
fruits
# Out:
# ['maat', 'neet', 'jam', 'ssamm']

# %%
L4=[fruit for fruit in fruits if fruit[0]=='s']
L4
# Out:
# ['ssamm']

# %%
D={"name":"smriti","gender":"female","Age":45}

# %%
D.items()
# Out:
# dict_items([('name', 'smriti'), ('gender', 'female'), ('Age', 45)])

# %%
D1={key:value for key,value in D.items()if len(key)>3}

# %%
D1
# Out:
# {'name': 'smriti', 'gender': 'female'}

# %%
L
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
D2 = {item:item**2 for item in L}

# %%
D2
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64}

# %%
D2 = {item:item**2 for item in L if item%2==0}

# %%
D2
# Out:
# {2: 4, 4: 16, 6: 36, 8: 64}
