# %%
#list, what is list, list vs array, create, access, delete, operation, functin

# %%
#list in  python are mutable
L=[1,2,3,4,5]

# %%
#add
L=[100,200]
L.append(1000)
L
# Out:
# [100, 200, 1000]

# %%
L.append("hello")
L
# Out:
# [100, 200, 1000, 'hello']

# %%
L.extend([500,600.700])
L
# Out:
# [100, 200, 1000, 'hello', 500, 600.7]

# %%
L.append([5,6])
L
# Out:
# [100, 200, 1000, 'hello', 500, 600.7, [5, 6], [5, 6]]

# %%
L.extend("goa")
L
# Out:
# [100, 200, 1000, 'hello', 500, 600.7, [5, 6], [5, 6], 'g', 'o', 'a']

# %%
L.insert(1,"world")
L
# Out:
# [100, 'world', 200, 1000, 'hello', 500, 600.7, [5, 6], [5, 6], 'g', 'o', 'a']

# %%
#array is homogenous
#list is hetrogenous

# %%
#delete
#del,remove,pop,clear

# %%
del L
L
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_57/1424664005.py in <cell line: 0>()
#       1 del L
# ----> 2 L
#
# NameError: name 'L' is not defined

# %%
L1=([1,2,3,4,5])
L1
# Out:
# [1, 2, 3, 4, 5]

# %%
del L1[0]
L1
# Out:
# [2, 3, 4, 5]

# %%
del L1[-1]
L1
# Out:
# [2, 3, 4]

# %%
L1.extend("goa")
L1
# Out:
# [2, 3, 4, 'goa', ['goa'], 'g', 'o', 'a']

# %%
del L1[-4]
L1
# Out:
# [2, 3, 4, 'goa', 'g', 'o', 'a']

# %%
del L1[-4]
L1
# Out:
# [2, 3, 'g', 'o', 'a']

# %%
L1.remove(3)
L1
# Out:
# [2, 'o', 'a']

# %%
L2=[4,6,8,9,10]
L2
# Out:
# [4, 6, 8, 9, 10]

# %%
L2.clear()
L2
# Out:
# []

# %%
#operations present in lists
L1+L1
# Out:
# [2, 'o', 'a', 2, 'o', 'a']

# %%
L1
# Out:
# [2, 'o', 'a']

# %%
L3=[1,2,3,[4,5]]
for i in L3:
    print(i)
# Out:
# 1
# 2
# 3
# [4, 5]

# %%
#membership
4 in L3
# Out:
# False

# %%
[4,5] in L3
# Out:
# True

# %%
#ffunctions that are present in list
l=[1,2,3,4]
len(l)
# Out:
# 4

# %%
min(l)
# Out:
# 1

# %%
max(l)
# Out:
# 4

# %%
sorted(l)
# Out:
# [1, 2, 3, 4]

# %%
sorted(l)
# Out:
# [1, 2, 3, 4]

# %%
sorted(l,reverse=True)
# Out:
# [4, 3, 2, 1]

# %%
l.sort(reverse=True) #sort will make change in a origianal list
l
# Out:
# [4, 3, 2, 1]

# %%
L3=[1,2,3,4,5]
L3.index(3)
# Out:
# 2
