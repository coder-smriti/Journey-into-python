# %%
#string->sequence of unicode char
#creating
c = 'Hello'
print(c)

# %%
'It is ranning outside'

# %%
c = ''''Hello'''
print(c)

# %%
c = """Heloo baby"""
print(c)
# Out:
# Heloo baby

# %%
print(c[0:5])
# Out:
# Heloo

# %%
print(c[2:])
# Out:
# loo baby

# %%
print(c[:])
# Out:
# Heloo baby

# %%
print(c)
# Out:
# Heloo baby

# %%
print(c[2:6:2])
# Out:
# lo

# %%
print(c[0:8:3])
# Out:
# Hob

# %%
print(c[0:6:-1])

# %%
print(c[-5:-1:2])
# Out:
#  a

# %%
print(c[::-1])
# Out:
# ybab ooleH

# %%
print(c[-1:5:-1])
# Out:
# ybab

# %%
c = "Hello"
print(c) #string are immutable(change) datatype
# Out:
# Hello

# %%
c = "World"
print(c)
# Out:
# World

# %%
#doesnt cahnge any one idex at athe same string but you can completely assign

# %%
 #deletion
c
# Out:
# 'World'

# %%
del c

# %%
 # print(c)

# %%
c = "Hello"

# %%
print(c)
# Out:
# Hello

# %%
#del c[0]
#print(c)

# %%
#del c[::3:2]

# %%
#operaton on string
#airthmatic operator
#relational operator
#logical operator
#loops on string
#Memmbership operation

# %%
"Hello" + "-" + "world"
# Out:
# 'Hello-world'

# %%
print("*"*50)
# Out:
# **************************************************

# %%
print("Hello"*4)
# Out:
# HelloHelloHelloHello

# %%
"Hello" == "World"
# Out:
# False

# %%
"Hello" != "world"
# Out:
# True

# %%
"Mumbai">"Pune"
# Out:
# False

# %%
"date"<"sum"
#Lexiographically-> jo alphabet pehle aat hai vo choti hoti hai
# Out:
# True

# %%
"Hello" and "world"
# ""(empty string) ko python false bolta hai
# aur non-empty koo python true bolta hai
# Out:
# 'world'

# %%
"Hello" or "World"
# Out:
# 'Hello'

# %%
not "Hello"
print(not "hello")
# Out:
# False

# %%
not ""
# Out:
# True

# %%
#loops and memmbersip operator
c = "Hello world"
for i in c:
    print(i)
# Out:
# H
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %%
c = "Hello world"
for i in c[2:7:2]:
    print(i)
# Out:
# l
# o
# w

# %%
c
# Out:
# 'Hello world'

# %%
'H' in c
# Out:
# True

# %%
'world' not in c
# Out:
# False

# %%
#function on string
#comman function
# len,min,max,sorted

# %%
c= "kolkata"
len(c)
# Out:
# 7

# %%
max(c) #onthe basis of ascii value
# Out:
# 't'

# %%
min(c)
# Out:
# 'a'

# %%
sorted(c,reverse=True)
# Out:
# ['t', 'o', 'l', 'k', 'k', 'a', 'a']
