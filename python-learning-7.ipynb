# %%
#functions
#abstraction(not visula but present)
#decompostion

# %%
def is_even(i):
    """you can know about this after reading it"""
    x=i%2==0
    return x
is_even(7)
# Out:
# False

# %%
def is_even(number):
#This function tells if a given number is odd or even
#input-any valid integer
#output-odd/even
#created by-smriti
#Last editied-11 may
 if number % 2 == 0:
    return "Even"
 else:
    return "Odd"
     
for i in range(1,11):
    print(is_even(i))

print(is_even.__doc__)
# Out:
# Odd
# Even
# Odd
# Even
# Odd
# Even
# Odd
# Even
# Odd
# Even
# None

# %%
# the 2 poinnt of view(make,used)
#parameter vs argument

# %%
def power(a,b):
        return a**b

# %%
power(2,3)
# Out:
# 8

# %%
power(3,2)
# Out:
# 9

# %%
#power(3)
#power(1)

# %%
def power(a=1,b=1):
        return a**b

# %%
power(2,3)
# Out:
# 8

# %%
power(2)
# Out:
# 2

# %%
power()
# Out:
# 1

# %%
power(2,3)
#behaviour is called positional argument
# Out:
# 8

# %%
power(b=2,a=3)
# Out:
# 9

# %%
#keyworment
print(1,2,3)
# Out:
# 1 2 3

# %%
def flexi(*number):
        product = 1
        for i in number:
                product = product*i
        print(product)

# %%
flexi(1)
# Out:
# 1

# %%
flexi(1,2)
# Out:
# 2

# %%
flexi(19,4)
# Out:
# 76

# %%
flexi(1,2,3,4,5,6,7)
# Out:
# 5040
