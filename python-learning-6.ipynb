# %%
#variable and memory reference
#inside in ram

# %%
# a
# python treated variable as name

# %%
a = 4

# %%
id(a)

# %%
hex(11654472)

# %%
id(4)

# %%
# pointing to the address 
# in python everything is an object so it isi call by object by reference

# %%
a=5
b=a
c=b

# %%
# aliasing
id(a)

# %%
id(b)

# %%
del a
a

# %%
id(b)

# %%
b

# %%
del b
b

# %%
c

# %%
id(c)

# %%
a = 5 
b = a
a = 6

# %%
b

# %%
#Reference counting
import sys

# %%
a = "casting"

# %%
b = a
c = b

# %%
id(a)

# %%
id(c)

# %%
id(b)

# %%
b

# %%
c

# %%
sys.getrefcount(a)

# %%
a

# %%
#garbage collection
#python after deleting memmory reference it doesn't delete the memory address

# %%
#garbage collector
#memory is present but that doen't stored anything
#free up

# %%
#weird stuff
#1.Getrefcoount anomly
#2.-5 to 256
#3.String
a=2
b=a
c=b

# %%
sys.getrefcount(a)

# %%
a=705
b=a
c=b

# %%
sys.getrefcount(a)

# %%
d=705
sys.getrefcount(a)

# %%
d=c #aliacing
sys.getrefcount(a)

# %%
a = 4
b = 4

# %%
id(a)

# %%
id(b)

# %%
a = 256
b = 256
id(a)

# %%
id(b)

# %%
a=257
b=257
id(a)

# %%
id(b)

# %%
a = -5
b = -5
id(a)

# %%
id(b)

# %%
a =-6
b =-6
id(a)

# %%
id(b)

# %%
# -5 to 256  (same id generated in this range)
# software optimazation

# %%
a=256
b=256

# %%
id(a)

# %%
id(b)

# %%
a="haldia"
b="haldia"

# %%
id(a)

# %%
id(b)

# %%
a = "indianinstituteoftechnology"
b = "indianinstituteoftechnology"

# %%
id(a)

# %%
id(b)

# %%
# jisme valid identifer(not ant char-> -,_etc) hota hai too same identity aayega

# %%
a = "indian_institute_of_technology"
b = "indian_institute_of_technology"

# %%
id(a)

# %%
id(b)

# %%
#how list are stored in memory
L = [1,2,3]
id(L)

# %%
id(L[0])

# %%
id(L[1])

# %%
id(L[2])

# %%
L[1]=1

# %%
L

# %%
id(L[1])

# %%
L=[1,2,3,[4,5]]

# %%
#Mutability
#abaility to cahnge data in his memmory is called mutable
#it depends on data types
#list,dictonary,sets
#strng,int,float,boolean,variable,tuple,complex

# %%
a="Hello"
a

# %%
id(a)

# %%
a+="world"
a

# %%
id(a)

# %%
#tuple
T = (1,2,3)
T

# %%
id(T)

# %%
L=[1,2,3,4]
L
# Out:
# [1, 2, 3, 4]

# %%
L1=L
L1
# Out:
# [1, 2, 3, 4]

# %%
id(L)
# Out:
# 136477911986432

# %%
L1.append(6)
L1
# Out:
# [1, 2, 3, 4, 6]

# %%
id(L1)
# Out:
# 136477911596288

# %%
L1
# Out:
# [1, 2, 3, 4, 6]

# %%
L
# Out:
# [1, 2, 3, 4, 6]

# %%
#now after mutating the list it also make the changes inoriginal list
#for reducing these mistakes we have to do CLONIG

# %%
#cloning
#not do this L1=L
#do this[:]

# %%
L1=L[:]

# %%
id(L)
# Out:
# 136477911596288

# %%
id(L1)
# Out:
# 136477911931648

# %%
L1.append(1)
L1
# Out:
# [1, 2, 3, 4, 6, 4, 4, 4, 1, 1, 1]

# %%
L
# Out:
# [1, 2, 3, 4, 6]

# %%
a=[1,2,3,[4,5]]
a
# Out:
# [1, 2, 3, [4, 5]]

# %%
a[-1][-1]=500
a
# Out:
# [1, 2, 3, [4, 500]]

# %%
a=[1,2,3[4,5]] #can't understand
a[-1][-1]=500
# Out:
# <>:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# /tmp/ipykernel_57/2786225702.py:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   a=[1,2,3[4,5]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_57/2786225702.py in <cell line: 0>()
# ----> 1 a=[1,2,3[4,5]]
#       2 a[-1][-1]=500
#
# TypeError: 'int' object is not subscriptable

# %%
a = [1,2]
b = [3,4]

# %%
c=(a,b)

# %%
c
# Out:
# ([1, 2], [3, 4])

# %%
id(a)
# Out:
# 136477911595840

# %%
id(b)
# Out:
# 136477911595648

# %%
c[0][0]=100
c
# Out:
# ([100, 2], [3, 4])

# %%
id(a)
# Out:
# 136477911595840

# %%
id(c)
# Out:
# 136478090016704

# %%
c
# Out:
# ([100, 2], [3, 4])

# %%
L=[1,2,3]
id(L)
# Out:
# 136478089316864

# %%
L = L+[4,5]
L
# Out:
# [1, 2, 3, 4, 5]

# %%
id(L)
# Out:
# 136477911881472

# %%
c
# Out:
# ([100, 2], [3, 4])
