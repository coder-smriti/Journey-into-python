# %%
python.org
downlod python
.py for making file

# %% [raw]
# print("Hello World")
# ASCII-
# print(32)
# print(45+90)

# %%
#variables
Name,age,price

# %%
import numpy as np
name="smriti"

# %%
name
# Out:
# 'smriti'

# %%
 My name is smriti,name
# Out:
#   Cell In[70], line 1
#     print My name is smriti,name
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
idenntifires
1variable

# %%
print type name
print type age 
print type prince

# %%
'''data types
integers,string,float,boolean,none'''
# Out:
# 'data types\nintegers,string,float,boolean,none'

# %%
#relational operater
#==,!=,<=,>=.<

# %%
#assigment operators
#=,+=,-+,*=./=,%=,**=

# %%
#logicaloperators
#true,false

# %%
#or-f,t(t)
#and-f,t(f)

# %%
#converstion-automatically
import numpy as np
a=2
b=3.4
sum= a+b

# %%
(sum)
# Out:
# 5.4

# %%
type((a)),type((b))
# Out:
# (int, float)

# %%
import numpy as np
a=2
b=4.25

# %%
(type(a)),(a+b)
# Out:
# (int, 6.25)

# %%
name=input("enter your age:")
# Out:
# enter your age: 19

# %%
import numpy as np
int=("3")
val=int(input("enter some value:")
# Out:
#   Cell In[87], line 3
#     val=int(input("enter some value:")
#                                       ^
# _IncompleteInputError: incomplete input

# %%
#str,conditional statement

# %%
str1 = "This is a string"
str2 = "Smriti"
str3 = """this is a string"""

# %%
#escape sequence character-\n,\t-for tab space
'''concatination-combine two string with+ operator'''
# Out:
# 'concatination-combine two string with+ operator'

# %%
str1 = "smriti"
len1 = len(str1)

# %% [raw]
# print(len1)

# %%
print(len1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 print(len1)
#
# TypeError: 'str' object is not callable

# %%
str[2]="-"
print(str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 str[2]="-"
#       2 print(str)
#
# TypeError: 'str' object does not support item assignment

# %%
#Slicing
#str[1:3]
'''str[:4],str[4:]'''
# Out:
# 'str[:4],str[4:]'

# %%
str="apple"
print(str[-3:-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 2
#       1 str="apple"
# ----> 2 print(str[-3:-1])
#
# TypeError: 'str' object is not callable

# %%
'''string function 
1.str.endswith()
2.str.capitaize()
3.str.replaced()
4.str.find()
5.str.count()'''
# Out:
# 'string function \n1.str.endswith-er\n2.str.capitaize()\n3.str.replaced\n4.str.final\n5.str.count'

# %%
import numpy as np
str="i am studying python from Apnacollage"
print(str.replace("python","html")
# Out:
#   Cell In[65], line 3
#     print(str.replace("python","html")
#                                       ^
# _IncompleteInputError: incomplete input

# %%
print(str.replaced("python","html")
# Out:
#   Cell In[67], line 1
#     print(str.replaced("python","html")
#                                        ^
# _IncompleteInputError: incomplete input

# %%
#conditional statemtent-if , elif, else

# %%
import numpy as np
num = int(input("enter number:")
          rem=num%2
# Out:
#   Cell In[79], line 2
#     num = int(input("enter number:")
#              ^
# SyntaxError: '(' was never closed

# %%
'''lists-mutable-access,change
strings-imortal-access'''

# %%
import numpy as np
