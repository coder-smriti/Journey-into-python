# %%
python.org
downlod python
.py for making file

# %% [raw]
# print("Hello World")
# ASCII-
# print(32)
# print(45+90)

# %%
#variables
Name,age,price

# %%
name="smriti"

# %%
print("name")
print(name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print("name")
#       2 print(name)
#
# TypeError: 'str' object is not callable

# %%
print My name is smriti,name

# %%
idenntifires
1variable

# %%
print type name
print type age 
print type prince

# %%
'''data types
integers,string,float,boolean,none'''
# Out:
# 'data types\nintegers,string,float,boolean,none'

# %%
#relational operater
#==,!=,<=,>=.<

# %%
#assigment operators
#=,+=,-+,*=./=,%=,**=

# %%
#logicaloperators
#true,false

# %%
#or-f,t(t)
#and-f,t(f)

# %%
#converstion-automatically
a=2
b=3.4
sum= a+b

# %%
print(sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 print(sum)
#
# TypeError: 'str' object is not callable

# %%
type((a)),type((b))
# Out:
# (int, float)

# %%
a=2
b=4.25

# %%
print(type(a)),print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 print(type(a)),print(a+b)
#
# TypeError: 'str' object is not callable

# %%
name=input("enter your age:")
val=int(input("enter some value:"))
print(type(val), (val))
# Out:
# enter your age: 19
# enter some value: 55
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 3
#       1 name=input("enter your age:")
#       2 val=int(input("enter some value:"))
# ----> 3 print(type(val), (val))
#
# TypeError: 'str' object is not callable
