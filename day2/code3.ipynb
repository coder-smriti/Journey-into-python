# %%
"""
this is multi line comment
"""
# Out:
# '\nthis is multi line comment\n'

# %%
# single line comment

# %%
a=1
b=5
sum=a+b
print(sum)
# Out:
# 6

# %%
# !pip install numpy
# !pip install pandas

# %%
a=1
b=5
sum=a+b
print(sum)

# %%
a=2
b=3.3
c="monika"

# %%
print(a,b,c)
# Out:
# 2 3.3 monika

# %%
print(type(a),type(b),type(c))
# Out:
# <class 'int'> <class 'float'> <class 'str'>

# %%
Names=["om","navya","nalni"]

# %%
Names.insert(11,"Rani")

# %%
print(Names)
# Out:
# ['om', 'Rahul', 'Rahul', 'Rahul', 'Rahul', 'Rahul', 'Rahul', 'Rahul', 'Rahul', 'navya', 'nalni', 'Rani']

# %%
box=["pen","scale"]

# %%
box.append("bottom")

# %%
print(box)
# Out:
# ['pen', 'scale', 'bottom', 'bottom', 'bottom']
